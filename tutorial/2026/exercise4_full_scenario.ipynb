# %% [markdown]
# # Exercise 4: Create your own scenario with multiple apps
# In this exercise, you are free to create a more complex and realistic scenario, for example a user that is chatting, looking up websites online, and is using Google Maps, all at the same time.
#
# See below how to instantiate multiple applications. If you would have multiple devices, you can even instantiate an application for another persona.

# %%
from puma.apps.android.google_chrome.google_chrome import GoogleChrome
from puma.apps.android.google_maps.google_maps import GoogleMapsActions
from puma.apps.android.teleguard.teleguard import TeleGuard

udid="emulator-5554"
udid2=""

alice_maps = GoogleMapsActions(udid)
alice_chrome = GoogleChrome(udid)
alice_teleguard = TeleGuard(udid)
# bob_teleguard = TeleGuard(udid2)

# %%
# Implement your scenario below. Be creative and create a consistent narrative
